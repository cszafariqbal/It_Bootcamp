# %% [markdown]
# <a href="https://colab.research.google.com/github/cszafariqbal/It_Bootcamp/blob/main/Data_visualization_Mall_customers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Import Library

# %%
from ast import increment_lineno
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #import Datasets

# %%
custumer_df = pd.read_csv('Mall_Customers.csv')
custumer_df
# Out:
#      CustomerID   Genre  Age  Annual_Income_(k$)  Spending_Score
# 0             1    Male   19                  15              39
# 1             2    Male   21                  15              81
# 2             3  Female   20                  16               6
# 3             4  Female   23                  16              77
# 4             5  Female   31                  17              40
# ..          ...     ...  ...                 ...             ...
# 195         196  Female   35                 120              79
# 196         197  Female   45                 126              28
# 197         198    Male   32                 126              74
# 198         199    Male   32                 137              18
# 199         200    Male   30                 137              83
#
# [200 rows x 5 columns]

# %% [markdown]
# check null values

# %%
custumer_df.isna().sum()
# Out:
# CustomerID            0
# Genre                 0
# Age                   0
# Annual_Income_(k$)    0
# Spending_Score        0
# dtype: int64

# %% [markdown]
# check data structure

# %%
custumer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CustomerID          200 non-null    int64
#  1   Genre               200 non-null    object
#  2   Age                 200 non-null    int64
#  3   Annual_Income_(k$)  200 non-null    int64
#  4   Spending_Score      200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %% [markdown]
# check statistic information

# %%
custumer_df.describe()
# Out:
#        CustomerID         Age  Annual_Income_(k$)  Spending_Score
# count  200.000000  200.000000          200.000000      200.000000
# mean   100.500000   38.850000           60.560000       50.200000
# std     57.879185   13.969007           26.264721       25.823522
# min      1.000000   18.000000           15.000000        1.000000
# 25%     50.750000   28.750000           41.500000       34.750000
# 50%    100.500000   36.000000           61.500000       50.000000
# 75%    150.250000   49.000000           78.000000       73.000000
# max    200.000000   70.000000          137.000000       99.000000

# %%
import seaborn as sns

# %% [markdown]
# #plot barplot of  Age and Annual Income

# %%
plt.figure(figsize=(12,8))
sns.barplot(data = data, x='Age', y='Annual_Income_(k$)')
plt.xlabel('Age')
plt.ylabel('Annual income k$')
plt.title('barplot of ages vs annual incomes k$ ')
plt.show()

# %% [markdown]
# #plot barplot of spending score and Annual Income

# %%
plt.figure(figsize=(12,8))
sns.barplot(data = data, x='Spending_Score', y='Annual_Income_(k$)')
plt.xlabel('Spending_Score')
plt.ylabel('Annual income k$')
plt.title('barplot of Spending_Score vs annual incomes ')
plt.show()

# %% [markdown]
# #plot barplot of Age and spending score

# %%
plt.figure(figsize=(12,8))
sns.barplot(data = data, x='Age', y='Spending_Score')
plt.xlabel('Age')
plt.ylabel('Spending_Score')
plt.title('barplot of ages vs Spending_Score ')
plt.show()

# %% [markdown]
# #plot scattor of Age and Annual Income

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(data = data, x='Age', y='Annual_Income_(k$)')
plt.xlabel('Age')
plt.ylabel('Annual income k$')
plt.title('scatterplot of ages vs annual incomes k$ ')
plt.show()

# %% [markdown]
# #plot boxplot of Age and Annual Income

# %%
plt.figure(figsize=(12,8))
sns.boxplot(data = data, x='Age', y='Annual_Income_(k$)')
plt.xlabel('Age')
plt.ylabel('Annual income k$')
plt.title('boxplot of ages vs annual incomes k$ ')
plt.show()

# %% [markdown]
# #plot pairplot of datasets

# %%
plt.figure(figsize=(12,8))
sns.pairplot(data, hue='Age')#(data = data, x='Age', y='Annual_Income_(k$)')
plt.show()

# %%
df = custumer_df
df
# Out:
#      CustomerID   Genre  Age  Annual_Income_(k$)  Spending_Score
# 0             1    Male   19                  15              39
# 1             2    Male   21                  15              81
# 2             3  Female   20                  16               6
# 3             4  Female   23                  16              77
# 4             5  Female   31                  17              40
# ..          ...     ...  ...                 ...             ...
# 195         196  Female   35                 120              79
# 196         197  Female   45                 126              28
# 197         198    Male   32                 126              74
# 198         199    Male   32                 137              18
# 199         200    Male   30                 137              83
#
# [200 rows x 5 columns]

# %% [markdown]
# #plot violinplot of Age and Annual Income

# %%
plt.figure(figsize=(10, 10))
ax = sns.violinplot(data=df, x='Age', y='Annual_Income_(k$)')

ax.set_xlabel('name of cars')
ax.set_ylabel('Price of city')
plt.title('Violin Plot of used car in city')

plt.show()

# %% [markdown]
# #plot countplot of Distrubution of Age

# %%
from seaborn.categorical import countplot
plt.figure(figsize=(10, 10))
sns.countplot(data=df, x='Age')
plt.show()

# %% [markdown]
# #plot countplot of Distrubution of Anual Income

# %%
from seaborn.categorical import countplot
plt.figure(figsize=(10, 10))
sns.countplot(data=df, x='Annual_Income_(k$)')
plt.show()
